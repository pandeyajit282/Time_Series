# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from datetime import datetime,timedelta
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error
from statsmodels.tsa.seasonal import seasonal_decompose
import pmdarima as  pm

# %%
def get_gold_price_data(start_date, end_date):
    gold_ticker = 'GC=F'
    
    gold_data = yf.download(gold_ticker, start=start_date, end=end_date)
    
    return gold_data


start_date = '2001-01-01'
end_date = '2023-01-01'

df = get_gold_price_data(start_date, end_date)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2001-01-02   268.399994   268.399994   268.399994   268.399994   268.399994
# 2001-01-03   268.000000   268.000000   268.000000   268.000000   268.000000
# 2001-01-04   267.299988   267.299988   267.299988   267.299988   267.299988
# 2001-01-05   268.000000   268.000000   268.000000   268.000000   268.000000
# 2001-01-08   268.000000   268.000000   268.000000   268.000000   268.000000
# ...                 ...          ...          ...          ...          ...
# 2022-12-23  1794.300049  1802.800049  1794.099976  1795.900024  1795.900024
# 2022-12-27  1803.400024  1826.300049  1803.400024  1814.800049  1814.800049
# 2022-12-28  1803.199951  1807.900024  1803.099976  1807.900024  1807.900024
# 2022-12-29  1805.800049  1819.500000  1805.800049  1819.500000  1819.500000
# 2022-12-30  1817.000000  1822.300049  1816.800049  1819.699951  1819.699951
#
#             Volume
# Date
# 2001-01-02       0
# 2001-01-03       1
# 2001-01-04       1
# 2001-01-05       0
# 2001-01-08       0
# ...            ...
# 2022-12-23      49
# 2022-12-27      69
# 2022-12-28     434
# 2022-12-29     277
# 2022-12-30      95
#
# [5520 rows x 6 columns]

# %%
df.drop(["Open", "High", "Low", "Adj Close", "Volume"], inplace=True,axis =1 )
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
def remove_outliers_iqr(data):
    # Step 1: Sort the data
    sorted_data = sorted(data)
    
    # Step 2: Calculate quartiles
    q1 = sorted_data[int(len(sorted_data) * 0.25)]
    q3 = sorted_data[int(len(sorted_data) * 0.75)]
    
    # Step 3: Calculate IQR
    iqr = q3 - q1
    
    # Step 4: Define outlier boundaries
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    
    # Step 5: Identify outliers
    outliers = [x for x in data if x < lower_bound or x > upper_bound]
    
    # Step 6: Remove outliers
    cleaned_data = [x for x in data if x >= lower_bound and x <= upper_bound]
    
    return cleaned_data, outliers


df["Close"], outliers = remove_outliers_iqr(df["Close"])

# %%
outliers      # Got no outliers
# Out:
# []

# %%
# Min-Max scaling
def normalize_data(data):

    min_vals = data.min()
    max_vals = data.max()
    
    normalized_data = (data - min_vals) / (max_vals - min_vals)
    
    return normalized_data

df.iloc[:,0] = normalize_data(df.iloc[:,0])

# %%
# downsampling
df = df.resample('M').mean()
df
# Out:
#                Close
# Date
# 2001-01-31  0.005718
# 2001-02-28  0.003733
# 2001-03-31  0.004003
# 2001-04-30  0.003329
# 2001-05-31  0.009451
# ...              ...
# 2022-08-31  0.839111
# 2022-09-30  0.792426
# 2022-10-31  0.785314
# 2022-11-30  0.818831
# 2022-12-31  0.858391
#
# [264 rows x 1 columns]

# %%
df1 = df.copy()

# %%
df.plot( figsize = (15,7), ylabel = "price", title=  " Gold price (monthly)")
# Out:
# <Axes: title={'center': ' Gold price (monthly)'}, xlabel='Date', ylabel='price'>

# %%
# ADF test for stationarity

result = adfuller(df["Close"])
print("ADF Test Results:")
print(f"ADF Statistic: {result[0]}")
print(f"P-value: {result[1]}")
print("Critical Values:")

for key, value in result[4].items():
    print(f"{key}: {value}")
# Out:
# ADF Test Results:
# ADF Statistic: -0.9950248251482429
# P-value: 0.7550745538641501
# Critical Values:
# 1%: -3.455558114028747
# 5%: -2.872635586277424
# 10%: -2.572682677000175

# %%
# first difference
df["differenced_close"] = df["Close"].diff().dropna()
df["differenced_close"].plot(figsize = (14,6))
# Out:
# <Axes: xlabel='Date'>

# %%
result = adfuller(df["differenced_close"].dropna())
print("ADF Test Results:")
print(f"ADF Statistic: {result[0]}")
print(f"P-value: {result[1]}")
print("Critical Values:")
for key, value in result[4].items():
    print(f"{key}: {value}")
# Out:
# ADF Test Results:
# ADF Statistic: -13.31120781378645
# P-value: 6.740842620961809e-25
# Critical Values:
# 1%: -3.455558114028747
# 5%: -2.872635586277424
# 10%: -2.572682677000175

# %%
# Perform seasonal decomposition
decomposition = seasonal_decompose(df["differenced_close"].dropna(), model='additive') 

# Plot the decomposed components
plt.figure(figsize=(12, 8))

plt.subplot(4, 1, 1)
plt.plot(decomposition.observed)
plt.title('Observed Data')

plt.subplot(4, 1, 2)
plt.plot(decomposition.trend)
plt.title('Trend')

plt.subplot(4, 1, 3)
plt.plot(decomposition.seasonal)
plt.title('Seasonality')

plt.subplot(4, 1, 4)
plt.plot(decomposition.resid)
plt.title('Residuals')

plt.tight_layout()
plt.show()

# %%
# Plotting PACF and PACF function of first difference for getting the non seasonal parameters i.e. (p,d,q)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
plot_acf(df["differenced_close"].dropna(), lags=40, ax=ax1)
plot_pacf(df["differenced_close"].dropna(), lags=40, ax=ax2)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# for seasonal 
df["seasonal_close"] = df["Close"].diff(12)
df
# Out:
#                Close  differenced_close  seasonal_close
# Date
# 2001-01-31  0.005718                NaN             NaN
# 2001-02-28  0.003733          -0.001985             NaN
# 2001-03-31  0.004003           0.000270             NaN
# 2001-04-30  0.003329          -0.000674             NaN
# 2001-05-31  0.009451           0.006122             NaN
# ...              ...                ...             ...
# 2022-08-31  0.839111           0.018191       -0.012666
# 2022-09-30  0.792426          -0.046684       -0.054156
# 2022-10-31  0.785314          -0.007112       -0.061549
# 2022-11-30  0.818831           0.033517       -0.052022
# 2022-12-31  0.858391           0.039561        0.003378
#
# [264 rows x 3 columns]

# %%
result = adfuller(df["seasonal_close"].dropna())
print("ADF Test Results:")
print(f"ADF Statistic: {result[0]}")
print(f"P-value: {result[1]}")
print("Critical Values:")
for key, value in result[4].items():
    print(f"{key}: {value}")
# Out:
# ADF Test Results:
# ADF Statistic: -2.4803650704615188
# P-value: 0.12032509774439276
# Critical Values:
# 1%: -3.458128284586202
# 5%: -2.873761835239286
# 10%: -2.5732834559706235

# %%
df["seasonal_close_differenced"] = df["seasonal_close"].diff()

# %%
result = adfuller(df["seasonal_close_differenced"].dropna())
print("ADF Test Results:")
print(f"ADF Statistic: {result[0]}")
print(f"P-value: {result[1]}")
print("Critical Values:")
for key, value in result[4].items():
    print(f"{key}: {value}")
# Out:
# ADF Test Results:
# ADF Statistic: -5.496752110304424
# P-value: 2.1150044088866643e-06
# Critical Values:
# 1%: -3.458128284586202
# 5%: -2.873761835239286
# 10%: -2.5732834559706235

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
plot_acf(df["seasonal_close_differenced"].dropna(), lags=60, ax=ax1)
plot_pacf(df["seasonal_close_differenced"].dropna(), lags=60, ax=ax2)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [raw]
# so we got model parameters as (1,1,1) and (4,1,1,12)

# %%
# training data 
train_data1 = df1.iloc[:234,:]
train_data1
# Out:
#                Close
# Date
# 2001-01-31  0.005718
# 2001-02-28  0.003733
# 2001-03-31  0.004003
# 2001-04-30  0.003329
# 2001-05-31  0.009451
# ...              ...
# 2020-02-29  0.746223
# 2020-03-31  0.745686
# 2020-04-30  0.801537
# 2020-05-31  0.814735
# 2020-06-30  0.824328
#
# [234 rows x 1 columns]

# %%
# Fit an SARIMAX model to the time series data
model = SARIMAX(train_data1["Close"], order=(1,1,1),seasonal_order=(4,1,1,12))
fitted_model = model.fit()

print(fitted_model.summary())
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                  234
# Model:             SARIMAX(1, 1, 1)x(4, 1, 1, 12)   Log Likelihood                 516.563
# Date:                            Sun, 03 Sep 2023   AIC                          -1017.127
# Time:                                    13:02:02   BIC                           -989.941
# Sample:                                01-31-2001   HQIC                         -1006.150
#                                      - 06-30-2020
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5107      0.201     -2.541      0.011      -0.905      -0.117
# ma.L1          0.6766      0.174      3.882      0.000       0.335       1.018
# ar.S.L12      -0.3422      0.157     -2.182      0.029      -0.649      -0.035
# ar.S.L24      -0.2297      0.113     -2.036      0.042      -0.451      -0.009
# ar.S.L36      -0.2898      0.103     -2.800      0.005      -0.493      -0.087
# ar.S.L48      -0.2294      0.100     -2.292      0.022      -0.426      -0.033
# ma.S.L12      -0.4760      0.165     -2.886      0.004      -0.799      -0.153
# sigma2         0.0005   4.07e-05     12.505      0.000       0.000       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.62   Jarque-Bera (JB):                19.55
# Prob(Q):                              0.43   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.70   Skew:                            -0.06
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# residuals from the model
res= fitted_model.resid

# %%
res.plot()     # no clear patterns in the residuals (a good sign)
# Out:
# <Axes: xlabel='Date'>

# %%
# Create a Q-Q plot of the residuals
sm.qqplot(res, line='s') 
plt.title('Q-Q Plot of Residuals')
plt.show()              # residuals follows approx normal distribution

# %%
# plotting acf and pacf of residuals 

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))
plot_acf(res, lags=20, ax=ax1)
plot_pacf(res, lags=10, ax=ax2)
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# Forecast future values using the fitted model
forecast_steps = 30

# Extract the test data for comparison
test_data1 = df1["Close"][-forecast_steps:]
len(test_data1)
# Out:
# 30

# %%
# Get the forecast and confidence intervals
forecast_results = fitted_model.get_forecast(steps=forecast_steps)
forecast = forecast_results.predicted_mean
conf_int = forecast_results.conf_int(alpha = 0.1)

# %%
# Calculate evaluation metrics
mae = mean_absolute_error(test_data1, forecast)
mse = mean_squared_error(test_data1, forecast)
rmse = np.sqrt(mse)
msle = mean_squared_log_error(test_data1, forecast)
mape = np.mean(np.abs((test_data1 - forecast) / test_data1)) * 100

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Squared Log Error (MSLE): {msle}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")
# Out:
# Mean Absolute Error (MAE): 0.05653499184277475
# Mean Squared Error (MSE): 0.005009424843423269
# Root Mean Squared Error (RMSE): 0.07077729044985594
# Mean Squared Log Error (MSLE): 0.0014316160666531658
# Mean Absolute Percentage Error (MAPE): 6.577112798483248

# %%
# plot the forecasted values and 90% confidence interval

plt.figure(figsize=(15, 7))
plt.plot(forecast.index, forecast, label='SARIMAX Forecast', color='blue')
plt.plot(df.index, df["Close"], label='Actual Data', color='green')
plt.fill_between(conf_int.index, conf_int.iloc[:, 0], conf_int.iloc[:, 1], color='gray', alpha=0.1, label='Confidence Intervals')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
plt.title('SARIMAX Forecast vs Actual Data with Confidence Intervals')
plt.show()

# %% [markdown]
# # Auto ARIMA

# %%
model = pm.auto_arima(train_data1["Close"], m = 12, seasonal =True, start_p = 0 ,d=1, start_q = 0,max_p=5, max_q = 5,
                     max_order = 5, test = "adf", stepwise=True, trace = True,D = 1,max_P = 5, max_Q =5)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=inf, Time=1.49 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=-909.888, Time=0.20 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=-974.236, Time=0.89 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=1.46 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=-909.864, Time=0.17 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=-987.786, Time=2.30 sec
#  ARIMA(1,1,0)(3,1,0)[12]             : AIC=-993.792, Time=4.15 sec
#  ARIMA(1,1,0)(4,1,0)[12]             : AIC=-1017.069, Time=7.16 sec
#  ARIMA(1,1,0)(5,1,0)[12]             : AIC=-1017.881, Time=22.09 sec
#  ARIMA(1,1,0)(5,1,1)[12]             : AIC=-1015.974, Time=34.12 sec

# %%
model.summary()

# %%
diag1 = model.plot_diagnostics(figsize=(15, 7))  # this only show the plot of ACF
plt.show()

# %%
# PACF 

res1 = model.resid()
fig, ax1  = plt.subplots(1, 1, figsize=(10, 4))
plot_pacf(res1, lags=10, ax=ax1)
plt.show()

# %%
forecast1 = model.predict(n_periods=30)

# %%
# Calculate evaluation metrics
mae = mean_absolute_error(test_data1, forecast1)
mse = mean_squared_error(test_data1, forecast1)
rmse = np.sqrt(mse)
msle = mean_squared_log_error(test_data1, forecast1)
mape = np.mean(np.abs((test_data1 - forecast1) / test_data1)) * 100

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Squared Log Error (MSLE): {msle}")
print(f"Mean Absolute Percentage Error (MAPE): {mape}")

# %%
# plot the second model's forecast 

plt.figure(figsize=(15, 7))
plt.plot(forecast1.index, forecast1, label='SARIMAX Forecast', color='blue')
plt.plot(df.index, df["Close"], label='Actual Data', color='green')
plt.xlabel('Date')
plt.ylabel('Values')
plt.legend()
plt.title('SARIMAX Forecast vs Actual Data')
plt.show()

# %%
forecast_diff = forecast - forecast1

# Plot the difference between both model's forecast with a horizontal line at y = 0
plt.figure(figsize=(10, 6))
forecast_diff.plot(ylim=(-0.1, 0.1))
plt.axhline(y=0, color='red', linestyle='--', )
plt.xlabel('Forecast Steps')
plt.ylabel('Difference')
plt.title('Difference between Forecasts')
plt.show()
